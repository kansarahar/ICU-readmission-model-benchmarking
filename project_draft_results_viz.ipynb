# %%
# Data for loss
loss_results = {
    "Phase": ["Training", "Validation", "Testing"],
    "Loss": [1503.391824901104, 168.17180049419403, 2297.280530691147]
}

# Creating a DataFrame for Loss
df_loss = pd.DataFrame(loss_results)

# Plotting Loss
plt.figure(figsize=(10, 6))
plt.plot(df_loss["Phase"], df_loss["Loss"], marker='o', color='red', label='Loss')

plt.title('ODE_RNN Model Loss')
plt.xlabel('Phase')
plt.ylabel('Loss Value')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Combined data for metrics and loss
data = {
    "Phase": ["Training", "Validation", "Testing"],
    "Accuracy Score": ["-", 0.5944010416666666, 0.599016497461929],
    "Average Precision Score": ["-", 0.15410293902675676, 0.15353185242067327],
    "ROC AUC Score": ["-", 0.6046086763695284, 0.607376305140814],
    "F1 Score": ["-", 0.27134502923976606, 0.27131738253098875],
    "Loss": [1503.391824901104, 168.17180049419403, 2297.280530691147]
}

df = pd.DataFrame(data)

# Create a figure and axis. Set the figure size as needed.
fig, ax = plt.subplots(figsize=(12, 2))

# Hide the axes
ax.axis('tight')
ax.axis('off')

# Create the table
table = ax.table(cellText=df.values, colLabels=df.columns, cellLoc = 'center', loc='center')

# Adjust table styles
table.auto_set_font_size(False)
table.set_fontsize(10)
table.auto_set_column_width(col=list(range(len(df.columns))))
table.scale(1, 2.5)  # The second number increases the cell height

# Style the table with colors
for key, cell in table.get_celld().items():
    if key[0] == 0:
        cell.set_facecolor('lightblue')  # Header color
        cell.set_text_props(weight='bold', color='black')
    else:
        cell.set_facecolor('white')

plt.savefig("model_performance_table.png", bbox_inches='tight', pad_inches=0.1)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Data from  training and testing results
data = {
    "Phase": ["Validation", "Testing"],
    "Accuracy Score": [0.5944010416666666, 0.599016497461929],
    "Average Precision Score": [0.15410293902675676, 0.15353185242067327],
    "ROC AUC Score": [0.6046086763695284, 0.607376305140814],
    "F1 Score": [0.27134502923976606, 0.27131738253098875]
}

df = pd.DataFrame(data)

# Create a 2x2 grid for plots
fig, axs = plt.subplots(2, 2, figsize=(12, 10))

# Plotting each metric in a separate subplot
axs[0, 0].plot(df["Phase"], df["Accuracy Score"], marker='o', color='blue')
axs[0, 0].set_title('Accuracy Score')
axs[0, 0].grid(True)

axs[0, 1].plot(df["Phase"], df["Average Precision Score"], marker='o', color='green')
axs[0, 1].set_title('Average Precision Score')
axs[0, 1].grid(True)

axs[1, 0].plot(df["Phase"], df["ROC AUC Score"], marker='o', color='red')
axs[1, 0].set_title('ROC AUC Score')
axs[1, 0].grid(True)

axs[1, 1].plot(df["Phase"], df["F1 Score"], marker='o', color='purple')
axs[1, 1].set_title('F1 Score')
axs[1, 1].grid(True)

# Adjust layout
plt.tight_layout()

# Save the entire grid as a PNG file
plt.savefig("metrics_grid.png")

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Extracted training information
training_info = {
    "Parameter": ["Data Path", "Batch Size", "Epochs", "Learning Rate", "Model Type", "CUDA Usage"],
    "Value": ["./data/preprocessed/data_arrays.npz", 32, 1, 0.001, "ode_rnn", "CPU"]
}

df = pd.DataFrame(training_info)

# Create a figure and axis. Set the figure size as needed.
fig, ax = plt.subplots(figsize=(12, 2))

# Hide the axes
ax.axis('tight')
ax.axis('off')

# Create the table
table = ax.table(cellText=df.values, colLabels=df.columns, cellLoc = 'center', loc='center')

# Adjust table styles
table.auto_set_font_size(False)
table.set_fontsize(10)
table.auto_set_column_width(col=list(range(len(df.columns))))
table.scale(1, 2.5)

# Style the table with colors
for key, cell in table.get_celld().items():
    if key[0] == 0:
        cell.set_facecolor('lightblue')  # Header color
        cell.set_text_props(weight='bold', color='black')
    else:
        cell.set_facecolor('white')

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Extracted test information
test_info = {
    "Parameter": ["Data Path", "Batch Size", "Model Type", "CUDA Usage"],
    "Value": ["./data/preprocessed/data_arrays.npz", 32, "ode_rnn", "CPU"]
}

df_test = pd.DataFrame(test_info)

# Create a figure and axis for the test info table. Set the figure size as needed.
fig, ax = plt.subplots(figsize=(12, 2))

# Hide the axes
ax.axis('tight')
ax.axis('off')

# Create the table
table_test = ax.table(cellText=df_test.values, colLabels=df_test.columns, cellLoc = 'center', loc='center')

# Adjust table styles
table_test.auto_set_font_size(False)
table_test.set_fontsize(10)
table_test.auto_set_column_width(col=list(range(len(df_test.columns))))
table_test.scale(1, 2.5)  # Increase the cell height

# Style the table with colors
for key, cell in table_test.get_celld().items():
    if key[0] == 0:
        cell.set_facecolor('lightblue')  # Header color
        cell.set_text_props(weight='bold', color='black')
    else:
        cell.set_facecolor('white')

plt.show()
